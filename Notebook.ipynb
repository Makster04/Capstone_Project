# %%
import pandas as pd

Cost_of_Living_df = pd.read_excel('Stats/NUMBEO_Cost_of_Living_Index.xlsx')
Cost_of_Living_df.head()
# Out:
#    Rank                         City  Cost of Living Index  Rent Index  \
# 0     1          Zurich, Switzerland                 107.4        61.4
# 1     2          Geneva, Switzerland                 104.2        58.6
# 2     3        Lausanne, Switzerland                 102.9        43.3
# 3     4           Basel, Switzerland                 102.1        46.4
# 4     5  New York, NY, United States                 100.0       100.0
#
#    Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                            87.0            108.9                   108.2
# 1                            84.0            107.7                   109.6
# 2                            76.6            107.1                   104.7
# 3                            77.4            108.4                   105.2
# 4                           100.0            100.0                   100.0
#
#    Local Purchasing Power Index
# 0                         159.7
# ...

# %%
Crime_and_Safety_df = pd.read_excel('Stats/NUMBEO_Crime_and_Safety_Index.xlsx')
Crime_and_Safety_df.head()
# Out:
#    Rank                            City  Crime Index  Safety Index
# 0     1  Pietermaritzburg, South Africa         82.2          17.8
# 1     2          Pretoria, South Africa         82.0          18.0
# 2     3              Caracas, Venezuela         81.4          18.6
# 3     4      Johannesburg, South Africa         80.8          19.2
# 4     5  Port Moresby, Papua New Guinea         80.7          19.3

# %%
Healthcare_df = pd.read_excel('Stats/NUMBEO_Crime_and_Safety_Index.xlsx')
Healthcare_df.head()
# Out:
#    Rank                            City  Crime Index  Safety Index
# 0     1  Pietermaritzburg, South Africa         82.2          17.8
# 1     2          Pretoria, South Africa         82.0          18.0
# 2     3              Caracas, Venezuela         81.4          18.6
# 3     4      Johannesburg, South Africa         80.8          19.2
# 4     5  Port Moresby, Papua New Guinea         80.7          19.3

# %%
Pollution_df = pd.read_excel('Stats/NUMBEO_Pollution_Index.xlsx')
Pollution_df.head()
# Out:
#    Rank                     City  Pollution Index  Exp Pollution Index
# 0     1         Kathmandu, Nepal             95.7                173.7
# 1     2  Tetovo, North Macedonia             95.6                174.3
# 2     3         Faridabad, India             94.5                171.0
# 3     4    Ulaanbaatar, Mongolia             94.4                174.0
# 4     5        Dhaka, Bangladesh             94.4                170.8

# %%
Property_Price_df = pd.read_excel('Stats/NUMBEO_Property_Price_Index.xlsx')
Property_Price_df.head()
# Out:
#    Rank                   City  Price To Income Ratio  \
# 0     1  Addis Ababa, Ethiopia                   56.0
# 1     2          Xiamen, China                   41.1
# 2     3        Shanghai, China                   37.9
# 3     4         Beijing, China                   37.1
# 4     5       Kathmandu, Nepal                   34.5
#
#    Gross Rental Yield City Centre  Gross Rental Yield Outside of Centre  \
# 0                             7.1                                   5.6
# 1                             1.0                                   1.2
# 2                             1.6                                   1.6
# 3                             1.5                                   1.8
# 4                             1.8                                   1.8
#
#    Price To Rent Ratio City Centre  \
# 0                             14.1
# 1                            103.3
# 2                             61.0
# 3                             65.1
# ...

# %%
Quality_of_life_df = pd.read_excel('Stats/NUMBEO_Quality_of_Life_Index.xlsx')
Quality_of_life_df.head()
# Out:
#    Rank                               City  Quality of Life Index  \
# 0     1  The Hague (Den Haag), Netherlands                  229.9
# 1     2             Luxembourg, Luxembourg                  229.1
# 2     3             Groningen, Netherlands                  226.6
# 3     4             Eindhoven, Netherlands                  222.3
# 4     5                 Basel, Switzerland                  216.7
#
#    Purchasing Power Index  Safety Index  Health Care Index  \
# 0                   155.0          79.5               81.0
# 1                   199.4          71.4               75.6
# 2                   154.7          78.1               78.6
# 3                   147.6          79.1               80.6
# 4                   191.7          72.4               71.6
#
#    Cost of Living Index  Property Price to Income Ratio  \
# 0                  64.2                             5.9
# 1                  71.0                             7.9
# ...

# %%
Traffic_df = pd.read_excel('Stats/NUMBEO_Traffic_Index.xlsx')
Traffic_df.head()
# Out:
#    Rank                            City  Traffic Index    Time Index  \
# 0   NaN                             NaN            NaN  (in minutes)
# 1   1.0                  Lagos, Nigeria          365.9            70
# 2   2.0            San Jose, Costa Rica          327.8          63.3
# 3   3.0  Los Angeles, CA, United States          312.4          56.8
# 4   4.0              Colombo, Sri Lanka          294.8            60
#
#    Time Exp. Index  Inefficiency Index  CO2 Emission Index
# 0              NaN                 NaN                 NaN
# 1          31345.9               491.7              9330.8
# 2          20163.8               350.3             10764.3
# 3          12153.3               682.4             14216.3
# 4          15838.9               401.4              7904.0

# %%
import pandas as pd

# Load the data
Ease_in_Doing_Business_Country_df = pd.read_excel('Stats/Ease_of_Doing_Business_per_Country.xlsx')

# Keep only the selected columns
cols_to_keep = [1, 2, 19, 31, 43, 55, 62, 79, 98, 118, 128, 136, 142]
Ease_in_Doing_Business_Country_df = Ease_in_Doing_Business_Country_df[cols_to_keep]

# Drop the first 5 rows (usually header info)
Ease_in_Doing_Business_Country_df = Ease_in_Doing_Business_Country_df.drop(index=[0, 1, 2, 3, 4, 5, 218, 219])

# Rename the columns properly
Ease_in_Doing_Business_Country_df.columns = [
    'Country',
    'City',
    'Starting_a_business score',
    'Dealing_with_construction_permits_score',
    'Getting_Electricity_score',
    'Registering_Property_score',
    'Getting_Credit_score',
    'Strength_of_minority_investors_protection_score',
    'Paying_taxes_score',
    'Trading_across_borders_score',
    'Enforcing_contracts_score',
    'Resolving_insolvency_score',
    'Overall_ease_of_doing_business_score'
]

# Show the cleaned DataFrame
Ease_in_Doing_Business_Country_df
# Out:
#                  Country                 City Starting_a_business score  \
# 6            Afghanistan          Afghanistan                        92
# 7                Albania              Albania                      91.8
# 8                Algeria              Algeria                        78
# 9                 Angola               Angola                      79.4
# 10   Antigua and Barbuda  Antigua and Barbuda                      82.6
# ..                   ...                  ...                       ...
# 238                  NaN                  NaN                       NaN
# 239                  NaN                  NaN                       NaN
# 240                  NaN                  NaN                       NaN
# 241                  NaN                  NaN                       NaN
# 242                  NaN                  NaN                       NaN
#
#     Dealing_with_construction_permits_score Getting_Electricity_score  \
# ...

# %%
import pandas as pd

# Load the Excel file
Ease_in_Doing_Business_City_df = pd.read_excel('Stats/Ease_of_Doing_Business_per_City.xlsx')



# Select only the specified columns by index
selected_columns = [3, 4, 16, 33, 50, 71, 87, 102, 123, 144, 175, 196]
Ease_in_Doing_Business_City_df= Ease_in_Doing_Business_City_df[selected_columns]

Ease_in_Doing_Business_City_df = Ease_in_Doing_Business_City_df.iloc[9:]

Ease_in_Doing_Business_City_df.columns = [
    'Country',
    'City',
    'Starting_a_business_score',
    'Dealing_with_construction_permits_score',
    'Getting_Electricity_score',
    'Registering_Property_score',
    'Getting_Credit_score',
    'Strength_of_minority_investors_protection_score',
    'Paying_taxes_score',
    'Trading_across_borders_score',
    'Enforcing_contracts_score',
    'Resolving_insolvency_score',
]

Ease_in_Doing_Business_City_df
# Out:
#          Country                City Starting_a_business_score  \
# 9    Afghanistan               Kabul                 92.076616
# 10   Afghanistan            Kandahar                 86.194263
# 11   Afghanistan               Balkh                 86.194263
# 12   Afghanistan           Nangarhar                 85.943007
# 13   Afghanistan               Herat                 85.943007
# ..           ...                 ...                       ...
# 872       Sweden           Sundsvall                 87.051116
# 873       Sweden                Umeå                 87.051116
# 874       Sweden             Uppsala                 87.051116
# 875     Tanzania       Zanzibar Town                 61.131077
# 876     Tanzania  Zanzibar Town-port                       NaN
#
#     Dealing_with_construction_permits_score Getting_Electricity_score  \
# 9                                 24.299712                 60.059303
# ...

# %%
import pandas as pd
import sqlite3

# Load CSV files into DataFrames
Ease_in_Doing_Business_City_df = pd.read_csv('Edited_Business_City_df.csv')
Ease_in_Doing_Business_Country_df = pd.read_csv('Edited_Business_Country_df.csv')

conn = sqlite3.connect(':memory:')

# Load DataFrames into the database as tables
Ease_in_Doing_Business_City_df.to_sql('BusinessCountry', conn, index=False, if_exists='replace')
Ease_in_Doing_Business_Country_df.to_sql('BusinessCity', conn, index=False, if_exists='replace')


# SQL query to merge all tables on 'Player'
sql_query = """
SELECT Ci Starting_a_business_score',
    'Dealing_with_construction_permits_score'.City
"""

All_Business_df = pd.read_sql_query(sql_query, conn)

# Save the merged DataFrame to a new CSV file
csv_filename = "Stats/All_Player_Numbers.csv"
All_Business_df.to_csv(csv_filename, index=False)

# Close the connection
conn.close()

# Provide the file to the user
All_Business_df
# Out:
#    Country     City  Starting_a_business score  \
# 0  Armenia  Armenia                       96.1
# 1  Armenia  Armenia                       96.1
# 2  Armenia  Armenia                       96.1
# 3    Niger    Niger                       91.5
# 4    Niger    Niger                       91.5
# 5    Niger    Niger                       91.5
#
#    Dealing_with_construction_permits_score  Getting_Electricity_score  \
# 0                                     73.1                       87.7
# 1                                     73.1                       87.7
# 2                                     73.1                       87.7
# 3                                     44.1                       52.7
# 4                                     44.1                       52.7
# 5                                     44.1                       52.7
#
#   Registering_Property_score Getting_Credit_score  \
# 0                       88.6                 70.0
# ...

# %%
import pandas as pd
import sqlite3

# Load CSV files into DataFrames
Cost_of_Living_df = pd.read_excel('Stats/NUMBEO_Cost_of_Living_Index.xlsx')
Crime_and_Safety_df = pd.read_excel('Stats/NUMBEO_Crime_and_Safety_Index.xlsx')
Healthcare_df = pd.read_excel('Stats/NUMBEO_Healthcare_Index.xlsx')
Pollution_df = pd.read_excel('Stats/NUMBEO_Pollution_Index.xlsx')
Property_Price_df = pd.read_excel('Stats/NUMBEO_Property_Price_Index.xlsx')
Quality_of_life_df = pd.read_excel('Stats/NUMBEO_Quality_of_Life_Index.xlsx')
Traffic_df = pd.read_excel('Stats/NUMBEO_Traffic_Index.xlsx')

conn = sqlite3.connect(':memory:')

# Load DataFrames into the database as tables
Cost_of_Living_df.to_sql('CostOfLiving', conn, index=False, if_exists='replace')
Crime_and_Safety_df.to_sql('CrimeSafety', conn, index=False, if_exists='replace')
Healthcare_df.to_sql('Healthcare', conn, index=False, if_exists='replace')
Pollution_df.to_sql('Pollution', conn, index=False, if_exists='replace')
Property_Price_df.to_sql('PropertyPrice', conn, index=False, if_exists='replace')
Quality_of_life_df.to_sql('QualityOfLife', conn, index=False, if_exists='replace')
Traffic_df.to_sql('Traffic', conn, index=False, if_exists='replace')



# SQL query to merge all tables on 'Player'
sql_query = """
SELECT *
From QualityOfLife
JOIN CostOfLiving ON QualityOfLife.City = CostOfLiving.City
JOIN CrimeSafety ON QualityOfLife.City = CrimeSafety.City
JOIN Healthcare ON QualityOfLife.City = Healthcare.City
JOIN Pollution ON QualityOfLife.City = Pollution.City
JOIN Traffic ON QualityOfLife.City = Traffic.City
JOIN PropertyPrice ON QualityOfLife.City = PropertyPrice.City


"""

# Execute the query and load results into a DataFrame
All_Numbeo_Numbers_df = pd.read_sql_query(sql_query, conn)

# Save the merged DataFrame to a new CSV file
csv_filename = "Stats/All_Player_Numbers.csv"
All_Numbeo_Numbers_df.to_csv(csv_filename, index=False)

# Close the connection
conn.close()

# Provide the file to the user
All_Numbeo_Numbers_df
# Out:
#      Rank                               City  Quality of Life Index  \
# 0       1  The Hague (Den Haag), Netherlands                  229.9
# 1       2             Luxembourg, Luxembourg                  229.1
# 2       4             Eindhoven, Netherlands                  222.3
# 3       7               Utrecht, Netherlands                  213.5
# 4       8             Rotterdam, Netherlands                  210.9
# ..    ...                                ...                    ...
# 200   256                       Cairo, Egypt                   77.0
# 201   257          Ho Chi Minh City, Vietnam                   75.8
# 202   259                       Tehran, Iran                   64.7
# 203   260                  Dhaka, Bangladesh                   64.4
# 204   261                Manila, Philippines                   63.2
#
#      Purchasing Power Index  Safety Index  Health Care Index  \
# 0                     155.0          79.5               81.0
# ...
